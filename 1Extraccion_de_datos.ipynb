# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-acc56f9f-8867-4db1-a6e8-62a190a37ad5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-acc56f9f-8867-4db1-a6e8-62a190a37ad5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 3             OMAR RODRIGUEZ GOMEZ   1.0        TP0001
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# ...

# %%
#Filtro por objeto
filtro1=df[df["NOMBRE_VENDEDOR"] == "LETICIA RAMIREZ HERNANDEZ"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 7     F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL   1.0      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 4               PÚBLICO EN GENERAL   2.0       BP00242
# 5               PÚBLICO EN GENERAL   2.0       BP00243
# 7        ANA BARBARA CRUZ PALACIOS   3.0        TP0001
# ...

# %%
#Convertir archivo filtrado a CSV
filtro1.to_csv("filtro1.csv")
from google.colab import files


files.download("filtro1.csv")
#Se filtran todas las ventas realizadas únicamente por LETICIA RAMIREZ HERNANDEZ

# %%
#Filtro por filas
filtro2= df.iloc[0:5,: ]
filtro2
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0   1.0  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1   1.0  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2   7.0    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
# 3   1.0    TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4   2.0   BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
#
# ...

# %%
#Convertir archivo filtrado a CSV
filtro2.to_csv("filtro2.csv")
from google.colab import files


files.download("filtro2.csv")
#Se filtran las primeras 5 filas junto con todas las columas

# %%
#Filtro por columnas
filtro3=df.iloc[ : , 1:10]
filtro3
# Out:
#       FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0    2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1    2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2    2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
# 3    2022-01-05   DIEGO ARMANDO LEON DURAN          OMAR RODRIGUEZ GOMEZ
# 4    2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# ...         ...                        ...                           ...
# 1421 2022-12-23  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 1422 2022-12-23  LETICIA RAMIREZ HERNANDEZ     LUIS ENRIQUE PATIÑO PEREZ
# 1423 2022-12-23  LETICIA RAMIREZ HERNANDEZ          SEVEN DAYS ALL SPORT
# 1424 2022-12-23  LETICIA RAMIREZ HERNANDEZ           REVUELTA MONTECARLO
# 1425 2022-12-23         AARON NUÑO CORDOVA                CPEG SOLUTIONS
#
#       CANT       CVE_ART                                     DESCR  \
# ...

# %%
#Convertir archivo filtrado a CSV
filtro3.to_csv("filtro3.csv")
from google.colab import files


files.download("filtro3.csv")
#Se filtran 10 columnas comenzando a partir de la segunda junto con todas las filas

# %%
#Filtro de filas vs columnas
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=2)
filtro4=df1.loc[["ALFREDO CANELA","DIEGO ARMANDO LEON DURAN"], ["CANT"]]
filtro4
# Out:
#                           CANT
# NOMBRE_VENDEDOR
# ALFREDO CANELA             5.0
# ALFREDO CANELA             7.0
# ALFREDO CANELA             3.0
# ALFREDO CANELA            30.0
# ALFREDO CANELA             6.0
# ...                        ...
# DIEGO ARMANDO LEON DURAN   5.0
# DIEGO ARMANDO LEON DURAN   2.0
# DIEGO ARMANDO LEON DURAN   3.0
# DIEGO ARMANDO LEON DURAN   1.0
# DIEGO ARMANDO LEON DURAN   1.0
#
# [455 rows x 1 columns]

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("filtro4.csv")
from google.colab import files


files.download("filtro4.csv")
#Se filtran las ventas de ALFREDO CANELA Y DIEGO ARMANDO LEON DURAN junto con la cantidad de productos que vendieron

# %%
#Filtro por cabecera
filtro5=df.head(10)
filtro5
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6  F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7  F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8  F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9  F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                         NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                   PÚBLICO EN GENERAL   1.0  TUE00244
# 1         JUAN ANTONIO RESENDIZ UGALDE   1.0  TUA00028
# 2            ANA BARBARA CRUZ PALACIOS   7.0    TP0007
# 3                 OMAR RODRIGUEZ GOMEZ   1.0    TP0001
# 4                   PÚBLICO EN GENERAL   2.0   BP00242
# 5                   PÚBLICO EN GENERAL   2.0   BP00243
# ...

# %%
#Convertir archivo filtrado a CSV
filtro5.to_csv("filtro5.csv")
from google.colab import files


files.download("filtro5.csv")
#Se filtran los primeros 10 registros

# %%
#Filtro por comparacion
filtro6=df[df["PRECIO_UNITARIO"] > 500]
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 1            JUAN ANTONIO RESENDIZ UGALDE   1.0      TUA00028
# 2               ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO   1.0       RP00165
# 8                      FIDEICOMISO F/1596   NaN      TUE00207
# ...

# %%
#Convertir archivo filtrado a CSV
filtro6.to_csv("filtro6.csv")
from google.colab import files


files.download("filtro6.csv")
#Se filtran las ventas cuyo precio unitario del producto supere los 500 pesos

# %%
#Filtro Y
filtro7=df[(df["MARGEN_TOTAL_CALCULADO"] >= 1000) & (df["FECHA_DOC"] >= "2022-08-01")]
filtro7
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 877   F38727 2022-08-01  LETICIA RAMIREZ HERNANDEZ
# 878   F38727 2022-08-01  LETICIA RAMIREZ HERNANDEZ
# 879   F38736 2022-08-02  LETICIA RAMIREZ HERNANDEZ
# 880   F38741 2022-08-03             ALFREDO CANELA
# 882   F38748 2022-08-04  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                                          NOMBRE_CLIENTE  CANT       CVE_ART  \
# 877                       VICTOR HUGO CASTELLANOS NUÑEZ   5.0        TP0011
# 878                       VICTOR HUGO CASTELLANOS NUÑEZ   5.0        TP0012
# 879   MANTENIMIENTO DE AIRE REFRIGERACION Y CALEFACC...   7.0      TUE00368
# ...

# %%
#Convertir archivo filtrado a CSV
filtro7.to_csv("filtro7.csv")
from google.colab import files


files.download("filtro7.csv")
#Se filtran las ventas cuyo margen total sea igual o mayor a 1000 y la fecha de la venta sea apartir del 1 de agosto

# %%
#Filtro O
filtro8=df[(df["MARGEN_TOTAL_CALCULADO"] >= 1000) | (df["FECHA_DOC"] >= "2022-08-01")]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10    F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                            NOMBRE_CLIENTE  CANT       CVE_ART  \
# 2               ANA BARBARA CRUZ PALACIOS   7.0        TP0007
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO   1.0       RP00165
# 8                      FIDEICOMISO F/1596   NaN      TUE00207
# 9                      FIDEICOMISO F/1596   NaN      TUE00207
# ...

# %%
#Convertir archivo filtrado a CSV
filtro8.to_csv("filtro8.csv")
from google.colab import files


files.download("filtro8.csv")
#Se filtran las ventas cuyo margen total sea igual o mayor a 1000 o la fecha de la venta sea apartir del 1 de agosto

# %%
#Filtro not
filtro9=df[~(df["CANT"] <= 1) & ~(df["FECHA_DOC"] <= "2022-07-01")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 763   F38507 2022-07-04             ALFREDO CANELA
# 765   F38513 2022-07-04  LETICIA RAMIREZ HERNANDEZ
# 766   F38514 2022-07-04  LETICIA RAMIREZ HERNANDEZ
# 769   F38524 2022-07-05             ALFREDO CANELA
# 772   F38534 2022-07-06  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                                      NOMBRE_CLIENTE  CANT       CVE_ART  \
# 763    PROVEEDORA DE SEGURIDAD INDUSTRIAL DEL GOLFO   7.0     ECQ-01444
# 765   COMERCIALIZADORA QUERETANA ESMERADO HERNANDEZ   2.0       BN00216
# 766                 FRANCISCO JAVIER MEDINA SANCHEZ   2.0      TUA00009
# ...

# %%
#Convertir archivo filtrado a CSV
filtro9.to_csv("filtro9.csv")
from google.colab import files


files.download("filtro9.csv")
#Se filtran las ventas que su cantidad no sea 1 y que su fecha de venta no sea igual o anterior al 1 de julio
